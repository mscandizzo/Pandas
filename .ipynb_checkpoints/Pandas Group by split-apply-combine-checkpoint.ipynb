# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import datetime as dt

# %% [markdown]
# ## List of Content
# -------------------------------
#
# 1. Clean white space
# 2. pandas reset index
# 3. Group by single field
# 4. Group --> first, last
# 5. Group --> get_group --> specific group after filtering by one category
# 6. Group by multiple fields
# 7. pandas set index
# 8. Groupby index levels
# 9. Data aggregation at index level
# 10. Data aggregation non index levels
# 11. Group -- get group --> gathering multiple fields
# 12. Group by multiple field to get specific field and data aggretion
# 13. Data aggregation -- many examples
# 14. data grouping and manipulation --> lambda functions
# 15. functions to apply to groupby --> rolling
# 16. apply functions to data after groupby
# 17.

# %%
datos = pd.read_excel(r'C:\Users\maria\OneDrive - Scandizzo & Partner, LLC\SPartners\Website\711\Stores Analysis\dump.xlsx',
                     sheetname='dump')

# %% [markdown]
# ## PSA category has white spaces which makes difficult to manipulate, let us fix it

# %%
datos['PSA'] = datos['PSA'].str.strip(' ')

# %%
datos.reset_index(inplace=True,drop=True)

# %% [markdown]
# ## Groupby
# -------------------------------

# %%
grouped = datos.groupby('UniqueField')
grouped.sum().head(3)
# Out:
#                     Store  RECEIPTNO  ItemCode  SuppCode  QtySold  unitcost  \
# UniqueField
# 0000013465 4000411      1       3465  140103.0      49.0        1      4.19
# 0000013466 4002402      1       3466  500024.0      30.0        1      5.00
# 0000013467 4004630      1       3467  120022.0      40.0        1      2.75
#
#                     COGS  SalesAmount  Promotion
# UniqueField
# 0000013465 4000411  4.19         6.25        0.0
# 0000013466 4002402  5.00         5.00        0.0
# 0000013467 4004630  2.75         3.50        0.0

# %%
grouped.first().head(3)
# Out:
#                     Store  RECEIPTNO  ItemCode  \
# UniqueField
# 0000013465 4000411      1       3465  140103.0
# 0000013466 4002402      1       3466  500024.0
# 0000013467 4004630      1       3467  120022.0
#
#                                                         Name  \
# UniqueField
# 0000013465 4000411  SAHA EGGS MEDIUM 6 S
# 0000013466 4002402  MOUNTAIN DEW 2.25L PET
# 0000013467 4004630  AL AIN LABAN 500ML
#
#                                   PSA                        Category  \
# UniqueField
# 0000013465 4000411  Other Daily Foods  Egg
# 0000013466 4002402           Beverage  Carbonated Beverage
# 0000013467 4004630    Dairy Beverages  Other
#
#                                             SubCat  SuppCode  \
# UniqueField
# 0000013465 4000411  Egg                                 49.0
# 0000013466 4002402  Carbonated Beverage                 30.0
# 0000013467 4004630  Other                               40.0
#
#                                           SuppName TransactionDate  QtySold  \
# UniqueField
# 0000013465 4000411  4 CORNER (PROCESSED FOOD)           2017-06-01        1
# 0000013466 4002402  DUBAI REFRESHMENT                   2017-06-01        1
# 0000013467 4004630  AL AIN FARMS FOR LIVESTOCK          2017-06-01        1
#
#                     unitcost  COGS  SalesAmount  Promotion YYYY-MM-DD
# UniqueField
# 0000013465 4000411      4.19  4.19         6.25        0.0 2017-06-01
# 0000013466 4002402      5.00  5.00         5.00        0.0 2017-06-01
# 0000013467 4004630      2.75  2.75         3.50        0.0 2017-06-01

# %%
grouped.last().head(3)
# Out:
#                     Store  RECEIPTNO  ItemCode  \
# UniqueField
# 0000013465 4000411      1       3465  140103.0
# 0000013466 4002402      1       3466  500024.0
# 0000013467 4004630      1       3467  120022.0
#
#                                                         Name  \
# UniqueField
# 0000013465 4000411  SAHA EGGS MEDIUM 6 S
# 0000013466 4002402  MOUNTAIN DEW 2.25L PET
# 0000013467 4004630  AL AIN LABAN 500ML
#
#                                   PSA                        Category  \
# UniqueField
# 0000013465 4000411  Other Daily Foods  Egg
# 0000013466 4002402           Beverage  Carbonated Beverage
# 0000013467 4004630    Dairy Beverages  Other
#
#                                             SubCat  SuppCode  \
# UniqueField
# 0000013465 4000411  Egg                                 49.0
# 0000013466 4002402  Carbonated Beverage                 30.0
# 0000013467 4004630  Other                               40.0
#
#                                           SuppName TransactionDate  QtySold  \
# UniqueField
# 0000013465 4000411  4 CORNER (PROCESSED FOOD)           2017-06-01        1
# 0000013466 4002402  DUBAI REFRESHMENT                   2017-06-01        1
# 0000013467 4004630  AL AIN FARMS FOR LIVESTOCK          2017-06-01        1
#
#                     unitcost  COGS  SalesAmount  Promotion YYYY-MM-DD
# UniqueField
# 0000013465 4000411      4.19  4.19         6.25        0.0 2017-06-01
# 0000013466 4002402      5.00  5.00         5.00        0.0 2017-06-01
# 0000013467 4004630      2.75  2.75         3.50        0.0 2017-06-01

# %%
grouped = datos.groupby(['Store','PSA'])
grouped.first().head(3)
# to see all the groups --> grouped.groups <-- visualization is not nice
# Out:
#                           UniqueField  RECEIPTNO  ItemCode  \
# Store PSA
# 1     Babies       0000016380 5004208       6380  670083.0
#       Bakery       0000013469 4015927       3469  150073.0
#       Beauty Aids  0000013603 4195649       3603  660035.0
#
#                                                        Name  \
# Store PSA
# 1     Babies       MERRIES BABY DIAPER PANTS SZ M
#       Bakery       DATE DELIGHT 50GM MODRN BAKRY
#       Beauty Aids  DOVE MENCARE INVISIBLEDRY150ML
#
#                                          Category  \
# Store PSA
# 1     Babies       Baby Supply
#       Bakery       Pastry
#       Beauty Aids  Men's Cosmetics
#
#                                            SubCat  SuppCode  \
# Store PSA
# 1     Babies       Baby Supply                         85.0
#       Bakery       Pastry                              32.0
#       Beauty Aids  Men's Cosmetics                     46.0
#
#                                          SuppName TransactionDate  QtySold  \
# Store PSA
# 1     Babies       KAO CORP                            2017-06-09        1
#       Bakery       MODERN BAKERY LLC                   2017-06-01        1
#       Beauty Aids  ALGURG UNILEVER (NON FOOD)          2017-06-01        1
#
#                    unitcost    COGS  SalesAmount  Promotion YYYY-MM-DD
# Store PSA
# 1     Babies         53.670  53.670         72.0        0.0 2017-06-09
#       Bakery          1.056   1.056          2.5        0.0 2017-06-01
#       Beauty Aids    12.500  12.500         15.0        0.0 2017-06-01

# %% [markdown]
# ## Groupby at Index Level
# --------------------------------------------
# 1. Grouping
# 2. aggregations

# %%
datos.set_index(['Store','YYYY-MM-DD'],inplace = True)

# %%
datos.groupby(level=0).sum()
# Out:
#        RECEIPTNO      ItemCode    SuppCode  QtySold    unitcost        COGS  \
# Store
# 1      106571848  5.553244e+09  10186306.0    21132   70620.710   80064.758
# 2      146168781  9.819042e+09  11968520.0    36050  130323.835  152518.399
# 3      136493857  6.261713e+09   6653759.0    23471   92476.846  105845.816
# 4       75391040  4.325060e+09   4750578.0    15018   47498.791   55272.174
# 5       60455507  5.191516e+09   8101634.0    17207   56644.781   62899.182
# 6      106648990  6.229335e+09   8124846.0    23486   79283.658   86508.968
# 7       84355882  5.667253e+09   6576422.0    23088   87865.386   99699.761
# 9      137800791  9.558050e+09  13737959.0    36460  121819.501  138212.494
# 10      69020973  6.264024e+09   7032949.0    20685   70145.146   76169.617
# 11      84867040  5.131984e+09   5863503.0    19359   67663.488   72681.668
# 12      66093772  3.170008e+09   3664973.0    10969   35597.235   40827.367
#
#        SalesAmount  Promotion
# Store
# 1        106374.71     2734.5
# 2        199445.23     1138.0
# 3        138801.10      798.0
# 4         71828.91      157.5
# 5         82174.53      321.5
# 6        116155.86      736.0
# 7        134156.88     3553.5
# 9        183744.05     2115.5
# 10        99572.29      491.0
# 11        97690.78     1429.5
# 12        52182.78     1101.0

# %%
datos.groupby(level='YYYY-MM-DD').sum().head(3)
# Out:
#             RECEIPTNO      ItemCode   SuppCode  QtySold   unitcost       COGS  \
# YYYY-MM-DD
# 2017-06-01   42141408  2.173735e+09  2740522.0     8000  28748.666  32014.103
# 2017-06-02   34274765  1.772427e+09  2142747.0     6364  22282.598  25622.352
# 2017-06-03   38456542  1.923379e+09  2190505.0     6719  23947.725  26878.434
#
#             SalesAmount  Promotion
# YYYY-MM-DD
# 2017-06-01     41902.35      589.5
# 2017-06-02     33188.19      240.5
# 2017-06-03     34731.06      325.5

# %%
# Important: It has to be an index level!!!

datos.sum(level='Store').head(3)
# Out:
#        RECEIPTNO      ItemCode    SuppCode  QtySold    unitcost        COGS  \
# Store
# 1      106571848  5.553244e+09  10186306.0    21132   70620.710   80064.758
# 2      146168781  9.819042e+09  11968520.0    36050  130323.835  152518.399
# 3      136493857  6.261713e+09   6653759.0    23471   92476.846  105845.816
#
#        SalesAmount  Promotion
# Store
# 1        106374.71     2734.5
# 2        199445.23     1138.0
# 3        138801.10      798.0

# %%
datos.groupby(['Store','PSA']).sum().head()
# Out:
#                    RECEIPTNO      ItemCode   SuppCode  QtySold  unitcost  \
# Store PSA
# 1     Babies            6380  6.700830e+05       85.0        1    53.670
#       Bakery         7536369  1.979373e+08    74630.0     1443  2875.808
#       Beauty Aids     258522  3.168528e+07     2212.0       48   784.660
#       Beverage      15682505  1.336788e+09   170951.0     3202  6346.180
#       Cigarette      6008876  5.671134e+08  1296531.0     1198  7216.700
#
#                        COGS  SalesAmount  Promotion
# Store PSA
# 1     Babies         53.670        72.00        0.0
#       Bakery       3165.938      4958.25        0.0
#       Beauty Aids   784.660       949.00        0.0
#       Beverage     7591.775      8240.25      156.0
#       Cigarette    8904.510     10187.50        0.0

# %% [markdown]
# ## Groupby.get_group follows SQL structure
# ---------------------------------------------------------------------
#
# get group must have as many filters as the initial group by has, i.e. --> 1 to 1 , 2 to 2, etc.

# %%
datos.groupby(['PSA']).get_group('Sandwiches').head(3)
# Out:
#     Store         UniqueField  RECEIPTNO  ItemCode  \
# 3       1  0000013468 4013146       3468   20071.0
# 42      1  0000013493 4073004       3493   20055.0
# 76      1  0000013511 4111201       3511   20020.0
#
#                                         Name         PSA  \
# 3   CHICKEN CHAWERMA                          Sandwiches
# 42  CHEESE DOG170 GM (MB)                     Sandwiches
# 76  EGG MAYONNAISE PARATHA165GM MB            Sandwiches
#
#                           Category                          SubCat  SuppCode  \
# 3   Wrap                            Wrap                               110.0
# 42  Sub Roll                        Sub Roll                            32.0
# 76  Wrap                            Wrap                                32.0
#
#                           SuppName TransactionDate  QtySold  unitcost  COGS  \
# 3   FRESH N BAKED PASTRIES LLC          2017-06-01        1       7.0   7.0
# 42  MODERN BAKERY LLC                   2017-06-01        1       4.0   4.0
# 76  MODERN BAKERY LLC                   2017-06-01        1       3.0   3.0
#
#     SalesAmount  Promotion YYYY-MM-DD
# 3          12.0        0.0 2017-06-01
# 42          6.0        0.0 2017-06-01
# 76          5.0        0.0 2017-06-01

# %%
datos.groupby(['YYYY-MM-DD','PSA']).get_group((dt.date(2017,6,20),'Sandwiches')).head(3)
# Out:
#         Store         UniqueField  RECEIPTNO  ItemCode  \
# 419800      1  0000015859 2093110       5859   20060.0
# 419839      1  0000015882 2132714       5882   20020.0
# 419861      1  0000015892 2145536       5892   20017.0
#
#                                             Name         PSA  \
# 419800  CHICKEN PARATHA165GM MODRN BKR            Sandwiches
# 419839  EGG MAYONNAISE PARATHA165GM MB            Sandwiches
# 419861  GRILLED CHICKEN BURGER175GR MB            Sandwiches
#
#                               Category                          SubCat  \
# 419800  Wrap                            Wrap
# 419839  Wrap                            Wrap
# 419861  Sub Roll                        Sub Roll
#
#         SuppCode                        SuppName TransactionDate  QtySold  \
# 419800      32.0  MODERN BAKERY LLC                   2017-06-20        1
# 419839      32.0  MODERN BAKERY LLC                   2017-06-20        1
# 419861      32.0  MODERN BAKERY LLC                   2017-06-20        1
#
#         unitcost  COGS  SalesAmount  Promotion YYYY-MM-DD
# 419800      3.25  3.25          5.5        0.0 2017-06-20
# 419839      3.00  3.00          5.0        0.0 2017-06-20
# 419861      4.70  4.70          8.0        0.0 2017-06-20

# %%
datos.groupby(['YYYY-MM-DD','PSA'])[['COGS','SalesAmount']].aggregate(np.sum).head(3)
# Out:
#                             COGS  SalesAmount
# YYYY-MM-DD PSA
# 2017-06-01 Babies         28.900        33.50
#            Bakery       1313.132      2040.50
#            Beauty Aids   417.090       494.25

# %%
datos.groupby(['YYYY-MM-DD','PSA']).size().head(3)
# Out:
# YYYY-MM-DD  PSA
# 2017-06-01  Babies           2
#             Bakery         436
#             Beauty Aids     32
# dtype: int64

# %%
grupodato = datos.groupby(['YYYY-MM-DD','PSA']).size().head(3)
print(grupodato.index.values[0])
print(grupodato.values[0])
# Out:
# (Timestamp('2017-06-01 00:00:00'), 'Babies')
# 2

# %%
grupodato.describe()
# Out:
# count      3.000000
# mean     156.666667
# std      242.374366
# min        2.000000
# 25%       17.000000
# 50%       32.000000
# 75%      234.000000
# max      436.000000
# dtype: float64

# %% [markdown]
# ## Aggregation functions
# ---------------------------------------

# %%
datos.groupby(['Store','PSA'])['SalesAmount'].agg([len,np.sum,np.mean,np.std]).head(3)
# Out:
#                       len      sum       mean       std
# Store PSA
# 1     Babies          1.0    72.00  72.000000       NaN
#       Bakery       1319.0  4958.25   3.759098  2.943691
#       Beauty Aids    48.0   949.00  19.770833  9.925766

# %%
datos.groupby(['Store','PSA'])['SalesAmount'].agg([len,np.sum,np.mean,np.std]).\
rename(columns={'len':'Qx.','sum':'Total','mean':'Avg.','std':'Var'}).head(3)
# Out:
#                       Qx.    Total       Avg.       Var
# Store PSA
# 1     Babies          1.0    72.00  72.000000       NaN
#       Bakery       1319.0  4958.25   3.759098  2.943691
#       Beauty Aids    48.0   949.00  19.770833  9.925766

# %%
datos.groupby(['Store','PSA']).agg({'SalesAmount': np.sum,'COGS':len}).head(3)
# Out:
#                    SalesAmount    COGS
# Store PSA
# 1     Babies             72.00     1.0
#       Bakery           4958.25  1319.0
#       Beauty Aids       949.00    48.0

# %% [markdown]
# ## Custom calculations with Lambda functions
# ----------------------------------------------------------------------

# %%
key = lambda x: x.day

zscore = lambda x: (x - x.mean()) / x.std()

datooss = datos.copy()
datooss = datooss[['YYYY-MM-DD','SalesAmount']]

# %%
datooss.set_index('YYYY-MM-DD',inplace=True)

# %%
datooss.head(3)
# Out:
#             SalesAmount
# YYYY-MM-DD
# 2017-06-01         6.25
# 2017-06-01         5.00
# 2017-06-01         3.50

# %%
transformed = datooss.groupby(key).transform(zscore)

# %%
transformed.plot(kind='hist',bins=50)

# %%
datiiss = datos.copy()
datiiss = datiiss[['YYYY-MM-DD','SalesAmount']]
datiiss.set_index(['YYYY-MM-DD'],inplace=True)

# %%
f = lambda x: x.fillna(x.max())
transformed = datiiss.transform(f)

# %%
transformed.head(3)
# Out:
#             SalesAmount
# YYYY-MM-DD
# 2017-06-01         6.25
# 2017-06-01         5.00
# 2017-06-01         3.50

# %%
datos.groupby('YYYY-MM-DD').rolling(4)['SalesAmount'].mean().head()
# Out:
# YYYY-MM-DD
# 2017-06-01  290977       NaN
#             290978       NaN
#             290979       NaN
#             290980    6.6875
#             290981    5.5000
# Name: SalesAmount, dtype: float64

# %%
datos.groupby('YYYY-MM-DD')['SalesAmount'].expanding().sum().head()
# Out:
# YYYY-MM-DD
# 2017-06-01  290977     6.25
#             290978    11.25
#             290979    14.75
#             290980    26.75
#             290981    28.25
# Name: SalesAmount, dtype: float64

# %%
datos.groupby('YYYY-MM-DD')['SalesAmount'].apply(lambda x:x.describe()).head()
# Out:
# YYYY-MM-DD
# 2017-06-01  count    6909.000000
#             mean        6.064894
#             std         7.383716
#             min      -100.000000
#             25%         2.000000
# Name: SalesAmount, dtype: float64

# %%
grupoos = datos.groupby('YYYY-MM-DD')['SalesAmount']

def f(group):
    return pd.DataFrame({'original': group,
                        'distance': group -group.mean()})

grupoos.apply(f).head()
# Out:
#         distance  original
# 290977  0.185106      6.25
# 290978 -1.064894      5.00
# 290979 -2.564894      3.50
# 290980  5.935106     12.00
# 290981 -4.564894      1.50
